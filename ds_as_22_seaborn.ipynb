# %%
import seaborn as sns

# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. Here are five types of plots that can be created using Seaborn, along with their uses:
#
# Histogram (sns.histplot): Histograms are used to plot the distribution of a single numerical variable. They partition the range of the variable into bins, and show the number of observations that fall in each bin.
#
# Bar Plot (sns.barplot): Bar plots are used for comparing the quantity of different categorical variables. They are useful when you want to compare a single category of data between individual sub-items.
#
# Scatter Plot (sns.scatterplot): Scatter plots are used to observe relationships between two numerical variables. The dots in a scatter plot not only report the values of individual data points, but also patterns when the data are taken as a whole.
#
# Box Plot (sns.boxplot): Box plots are used to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile, and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median.
#
# Heatmap (sns.heatmap): Heatmaps are used to visualize data in 2D rectangular data. It’s a way of representing the data in a 2-dimensional form. The data values are represented as colors in the graph. The goal of the heatmap is to provide a colored visual summary of information.

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x=fmri.timepoint, y=fmri.signal, hue=fmri.event, style=fmri.region)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
titanic=sns.load_dataset("titanic")

# %%
sns.boxplot(x=titanic.pclass,y=titanic.age)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x=titanic.pclass,y=titanic.fare)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
diamond=sns.load_dataset("diamonds")

# %%
sns.histplot(diamond["price"],hue=diamond["cut"])

# %% [markdown]
# this will give an error beacuse of cut columns values in diamond dataframe

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
iris=sns.load_dataset("iris")

# %%
sns.pairplot(iris,hue="species")
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
flights = sns.load_dataset("flights")

# %%
flights = flights.pivot(index='month', columns='year', values='passengers')
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt='d', cmap='YlGnBu')
plt.show()
